# %%
import numpy as np
import os

# id1 = 20
# id2 = 21
# pose_id1 = np.load(os.path.join('reconstructions', f'online_test{id1}', 'poses.npy'))
# pose_id2 = np.load(os.path.join('reconstructions', f'online_test{id2}', 'poses.npy'))
# print(pose_id1.shape)
# print(pose_id2.shape)
# print(pose_id1[18, :])
# print(pose_id2[18, :])

# %%
pose_offline = np.load("/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_ipad_offline/poses.npy")
print(pose_offline)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  1.00000000e+00]
#  [-1.27857877e-02 -7.27523025e-03  1.08130341e-02  5.99847827e-03
#   -5.22261895e-02  8.43948033e-03  9.98581231e-01]
#  [ 8.62246752e-02 -9.29717626e-03  2.51080710e-02  8.22841097e-03
#   -9.71120298e-02 -1.13300299e-02  9.95175183e-01]
#  [ 2.21210390e-01 -1.64592657e-02  3.19164656e-02  2.25179475e-02
#   -1.96510941e-01 -4.12160680e-02  9.79376078e-01]
#  [ 3.38130087e-01 -1.39870727e-02  6.50651902e-02  2.94702705e-02
#   -2.82112777e-01 -4.80799116e-02  9.57722247e-01]
#  [ 4.17520285e-01 -3.01877875e-02  1.42821744e-01  6.59144716e-03
#   -3.69897395e-01 -5.66926897e-02  9.27318275e-01]
#  [ 4.57865924e-01 -6.07522428e-02  2.19551802e-01  1.42013980e-02
#   -4.74526733e-01 -8.15492645e-02  8.76341105e-01]
#  [ 5.38860857e-01 -6.50128424e-02  2.61239260e-01  3.04960124e-02
#   -5.59082150e-01 -9.87095013e-02  8.22650552e-01]
# ...

# %%
pose_offline = np.load("/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_realsense_offline_ellipse_with_depth_2/poses.npy")
pose_errors = []
for i in range(9, 53):
# for i in range(8, 57, 8):
    pose_online = np.load(f"/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_realsense_online_ellipse_with_depth_delay5/pic{i:03d}/poses.npy")
    print(pose_online)
    # pose_error = pose_offline[i, :] - pose_online
    # pose_error = pose_offline[i-8:i, :] - pose_online
    # print(pose_error.shape)
    # print("######")
    # print(pose_online.shape)
    # pose_errors.append(pose_error)

# print(pose_offline[45, :])
# print(np.load(f"/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_realsense_online_ellipse_with_depth_2/pic046/poses.npy"))
# print(np.array(pose_errors).shape)
# pose_errors = np.array(pose_errors).reshape(44, 7)
# pose_errors = np.concatenate(pose_errors, axis=0)
# print(pose_errors.shape)
# print(np.max(abs(pose_errors[:, 0])))
# print(np.argmax(abs(pose_errors[:, 0])))
# print(np.max(abs(pose_errors[:, 0])))
# print(np.argmax(abs(pose_errors[:, 1])))
# print(np.max(abs(pose_errors[:, 0])))
# print(np.argmax(abs(pose_errors[:, 2])))
# print(np.min(abs(pose_errors[:, 0])))
# print(np.min(abs(pose_errors[:, 1])))
# print(np.min(abs(pose_errors[:, 2])))

# pose_online = np.load("/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_ipad_online_ba8/pic8/poses.npy")
# print(pose_online)
# print(pose_offline[0:8, :])
# print(pose_offline[0:8, :] - pose_online)
# Out:
# [[ 1.6764668   0.03206166  1.1134944   0.0100236  -0.71793544 -0.00327008
#    0.6960295 ]]
# [[ 1.7273936   0.00502228  1.5508951   0.0107944  -0.78852504 -0.0066382
#    0.6148719 ]]
# [[ 1.6609019e+00  2.2326684e-02  1.9066852e+00  8.4893610e-03
#   -8.4687859e-01 -1.7835580e-04  5.3171885e-01]]
# [[ 1.4813995e+00  2.5686830e-02  2.2862310e+00  1.4836055e-02
#   -8.9630854e-01  9.1262721e-04  4.4318131e-01]]
# [[ 1.2507819   0.08174641  2.530364    0.00903659 -0.9390363   0.01341286
#    0.34343663]]
# [[ 9.4130105e-01  8.4184483e-03  2.8911619e+00  6.2972298e-03
#   -9.7008842e-01  1.3394968e-03  2.4266614e-01]]
# [[ 0.42303005  0.0741417   2.982871    0.00641496 -0.9904739   0.01366076
#    0.13686973]]
# [[ 0.05106547  0.04481068  3.0656853   0.0090377  -0.99942076  0.01035446
#    0.03112775]]
# [[-0.31765458  0.09646554  2.9727552   0.00656516 -0.9973381   0.018153
#   -0.07030921]]
# [[-0.6791115   0.06271238  2.8321178   0.01134077 -0.9839479   0.01650166
#   -0.17732893]]
# ...

# %%
pose_errors = []
pose_online = np.load("/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_realsense_online_ellipse_with_depth_ba8/pic008/poses.npy")
print(pose_online)
# print(pose_offline[8:16])
# pose_error = pose_offline[8:16, :] - pose_online
# print(pose_error)
# pose_errors.append(pose_error)
# Out:
# [[ 1.18765915e-04  1.44681268e-04 -6.87501102e-04  1.58895284e-03
#   -8.17709193e-02 -6.01529097e-03  9.96631265e-01]
#  [ 2.94543564e-01 -1.10694887e-02 -2.88403463e-02  4.64902696e-04
#   -1.89325228e-01 -7.04277540e-03  9.81889188e-01]
#  [ 5.50894678e-01 -2.32275529e-03  1.04168886e-02  8.62479676e-04
#   -2.88880378e-01 -5.75387292e-03  9.57348108e-01]
#  [ 8.43570113e-01 -1.14959665e-02  5.51580191e-02 -2.95980368e-03
#   -3.79624635e-01 -2.01854692e-03  9.25134063e-01]
#  [ 1.12855482e+00 -1.38443708e-02  2.72340447e-01  3.92451789e-03
#   -4.82643038e-01 -4.89059277e-03  8.75794768e-01]
#  [ 1.31683683e+00  2.33117919e-02  4.56699908e-01  2.44362047e-03
#   -5.64431310e-01  8.47142935e-03  8.25433075e-01]
#  [ 1.54023588e+00  1.84415076e-02  7.16381967e-01 -5.83037967e-03
#   -6.49353325e-01  1.21446969e-02  7.60366917e-01]
#  [ 1.53504813e+00  1.95461363e-02  7.15615809e-01  4.88697598e-03
#   -6.39542937e-01 -4.37199743e-03  7.68726885e-01]]

# %%
pose_online = np.load("/remote-home/ums_sunjiahao/droid-slam/reconstructions/bear_room_ipad_online_ba8/pic24/poses.npy")
pose_error = pose_offline[16:24, :] - pose_online
print(pose_error)
pose_errors.append(pose_error)
# Out:
# [[ 1.30103752e-02  2.13888437e-02 -1.44541621e-01  3.87083739e-04
#   -6.23464584e-05 -1.11714005e-04  1.25702471e-03]
#  [ 1.59365982e-02  2.58974880e-02 -1.40420794e-01  4.22725454e-04
#   -1.24573708e-04 -1.08912587e-04  1.25152618e-03]
#  [ 3.73672843e-02  3.29023302e-02 -1.30865216e-01  4.56583104e-04
#   -2.98678875e-04 -6.99311495e-05  1.18204951e-03]
#  [ 5.90110421e-02  1.92053616e-02 -1.18674755e-01  3.40495259e-04
#   -5.18918037e-04 -4.58657742e-05  1.19984150e-03]
#  [ 6.23835325e-02  2.01067775e-02 -1.08731747e-01  3.53264622e-04
#   -6.12258911e-04 -4.23640013e-05  1.17954612e-03]
#  [ 7.36271143e-02  1.45669430e-02 -8.70454311e-02  2.77840067e-04
#   -7.43031502e-04  3.03611159e-05  1.08349323e-03]
#  [ 7.02615976e-02  1.16294771e-02 -7.72097707e-02  3.12139280e-04
#   -8.01444054e-04  4.02033329e-05  1.00678205e-03]
#  [ 6.60615563e-02  1.03469640e-02 -6.96151257e-02  3.59747559e-04
#   -8.45193863e-04  1.32620335e-06  9.62674618e-04]]

# %%
pose_error = pose_offline[16:24, :] - pose_online
print(pose_error)
pose_errors.append(pose_error)
# Out:
# [[ 1.30103752e-02  2.13888437e-02 -1.44541621e-01  3.87083739e-04
#   -6.23464584e-05 -1.11714005e-04  1.25702471e-03]
#  [ 1.59365982e-02  2.58974880e-02 -1.40420794e-01  4.22725454e-04
#   -1.24573708e-04 -1.08912587e-04  1.25152618e-03]
#  [ 3.73672843e-02  3.29023302e-02 -1.30865216e-01  4.56583104e-04
#   -2.98678875e-04 -6.99311495e-05  1.18204951e-03]
#  [ 5.90110421e-02  1.92053616e-02 -1.18674755e-01  3.40495259e-04
#   -5.18918037e-04 -4.58657742e-05  1.19984150e-03]
#  [ 6.23835325e-02  2.01067775e-02 -1.08731747e-01  3.53264622e-04
#   -6.12258911e-04 -4.23640013e-05  1.17954612e-03]
#  [ 7.36271143e-02  1.45669430e-02 -8.70454311e-02  2.77840067e-04
#   -7.43031502e-04  3.03611159e-05  1.08349323e-03]
#  [ 7.02615976e-02  1.16294771e-02 -7.72097707e-02  3.12139280e-04
#   -8.01444054e-04  4.02033329e-05  1.00678205e-03]
#  [ 6.60615563e-02  1.03469640e-02 -6.96151257e-02  3.59747559e-04
#   -8.45193863e-04  1.32620335e-06  9.62674618e-04]]

# %%
print(type(pose_errors))
print(np.array(pose_errors).reshape(24, 7).shape)
print(np.max(abs(np.array(pose_errors)[:, :, 0])))
print(np.max(abs(np.array(pose_errors)[:, :, 1])))
print(np.max(abs(np.array(pose_errors)[:, :, 2])))
print(np.min(abs(np.array(pose_errors)[:, :, 0])))
print(np.min(abs(np.array(pose_errors)[:, :, 1])))
print(np.min(abs(np.array(pose_errors)[:, :, 2])))
# Out:
# <class 'list'>
# (24, 7)
# 0.101707995
# 0.03290233
# 0.18905902
# 0.006617103
# 0.0036600195
# 0.045492023
